# %%
import os
import pandas as pd

# %%
df_toys=pd.read_excel('Toy Building Tracker.xlsx',sheet_name='Toy Building Tracker') #Elf Name Lookup

# %%
df_toys.columns[]
# = ['a','b']
#df_toys.iloc[0,:2].values
# Out:
# 'Toy Building Tracker'

# %%
df_toys
# Out:
#                               Toy Building Tracker Unnamed: 1  \
# 0                                              Toy      Quota
# 1            Number of Children on the Nicest List  200000000
# 2                             Barbie's Dream House        0.4
# 3                                             Bike        0.3
# 4                                   Large Lego Set        0.3
# 5   Number of Children on the Nicer than Most List  300000000
# 6                           Barbie Convertible Car       0.25
# 7                                  Medium Lego Set       0.25
# 8                                          Scooter       0.25
# 9                                       Board Game        0.1
# 10                                    Squishmallow       0.15
# 11             Number of Children on the Nice List  500000000
# 12                                     Barbie Doll       0.35
# 13                                  Small Lego Set        0.2
# ...
