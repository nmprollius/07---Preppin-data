# %% [markdown]
# ### 2021: Week 29 - PD x WOW - Tokyo 2020 Calendar
#
# https://preppindata.blogspot.com/2021/07/2021-week-29-pd-x-wow-tokyo-2020.html
#
# July 20, 2021
# Challenge by Tom Prowse with collaboration with the Workout Wednesday team!
#
# This week is time for our annual get together with Workout Wednesday for a joint challenge so that you can have a full data prep to visualisation solution.
#
# Unfortunately the Olympics was postponed in 2020, so for last year's collaboration we looked at historical winners through the history of the games. However, this year, Japan 2020 is going ahead so we thought it would be the perfect time to create an event calendar to help us keep track of the events that we don't want to miss.
#
# Inputs
# The data comes from the Olympics website. (Note; this was taken on Wednesday 14th July so the schedule for some events may have changed since!). You can download the data here.
#
# ### Requirements
# Input the Data
#
# Create a correctly formatted DateTime field (hint)
#
# Parse the event list so each event is on a separate row (hint)
#
# Group similar sports into a Sport Type field (hint)
#
# Combine the Venue table (hint)
#
# Calculate whether the event is a 'Victory Ceremony' or 'Gold Medal' event.
#
# (Note, this might not pick up all of the medal events.)

# %%
import os
import pandas as pd
import shutil
import datetime as dt
envir = os.environ['USERPROFILE']

# %%
# #copy data
# from_file = fr'{envir}\downloads\Olympic Events.xlsx'
# to_file = fr'{envir}\Documents\02 - Weekly\07 - Preppin data\20210722\Olympic Events.xlsx'
# shutil.move(from_file,to_file)

# %%
to_file = fr'{envir}\Documents\02 - Weekly\07 - Preppin data\20210722\Olympic Events.xlsx'
events = pd.read_excel(to_file,sheet_name = 'Olympics Events')
venues = pd.read_excel(to_file,sheet_name = 'Venues')

# %%
for a in [events,venues]:
    a.columns = [i.lower().replace(' ','_').strip() for i in a ]
events['date'].unique()
# Out:
# array(['21st_July_2021', '22nd_July_2021', '22_July_2021',
#        '23rd_July_2021', '24th_July_2021', '25th_July_2021',
#        '26th_July_2021', '27th_July_2021', '28th_July_2021',
#        '29th_July_2021', '30th_July_2021', '31st_July_2021',
#        '1st_August_2021', '2nd_August_2021', '3rd_August_2021',
#        '4th_August_2021', '5th_August_2021', '6th_August_2021',
#        '7th_August_2021', '8th_August_2021'], dtype=object)

# %%
events['date']= events['date'].replace({'22_July_2021':'22nd_July_2021'})
events['day'] = events['date'].apply(lambda x:x.split('_')[0][:-2])

events['month'] = events['date'].apply(lambda x:x.split('_')[1])
events['year'] = events['date'].apply(lambda x:x.split('_')[2])
events['day']=events['day'].apply(lambda x:x.zfill(2))

events['date1'] = events['year']+events['month']+events['day']
events['date'] = pd.to_datetime(events['date1'],format='%Y%B%d')

# %%
events.drop(columns=['day','month','year','date1'],inplace=True)

# %%
eventclms = events['events'].str.split(',',expand=True)

# %%
eventscopy = events.merge(eventclms,left_index=True,right_index=True).copy()
eventscopy.drop(columns='events',inplace=True)
eventscopy = eventscopy.melt(id_vars=['date',  'time', 'sport', 'venue']).copy()
eventscopy= eventscopy[~eventscopy['value'].isna()].copy()
eventscopy.drop(columns='variable',inplace=True)
eventscopy.rename(columns={'value':'event'},inplace=True)
eventscopy.reset_index(drop=True,inplace=True)
eventscopy
# Out:
#            date  time              sport                             venue  \
# 0    2021-07-21  1:00  Baseball/Softball  Fukushima Azuma Baseball Stadium
# 1    2021-07-21  8:30           Football                      Sapporo Dome
# 2    2021-07-21  9:00           Football                    Miyagi Stadium
# 3    2021-07-21  9:30           Football                     Tokyo Stadium
# 4    2021-07-22  1:00  Baseball/Softball  Fukushima Azuma Baseball Stadium
# ...         ...   ...                ...                               ...
# 1890 2021-07-28  0:30             Rowing               Sea Forest Waterway
# 1891 2021-07-29  0:30             Rowing               Sea Forest Waterway
# 1892 2021-07-29  0:30             Rowing               Sea Forest Waterway
# 1893 2021-07-29  0:30             Rowing               Sea Forest Waterway
# 1894 2021-07-29  0:30             Rowing               Sea Forest Waterway
#
#                                            event
# 0                             Australia vs Japan
# 1        Women's Group E: Great Britain vs Chile
# 2               Women's Group F: China vs Brazil
# 3       Women's Group G: Sweden vs United States
# 4                        United States vs Canada
# ...                                          ...
# 1890          Men's Single Sculls Semifinals A/B
# 1891     Lightweight Men's Double Sculls Final B
# 1892   Lightweight Women's Double Sculls Final B
# 1893               Women's Single Sculls Final D
# 1894                 Men's Single Sculls Final D
#
# [1895 rows x 5 columns]

# %%
eventscopy['sport'] = eventscopy['sport'].str.title()

# %%
mapper = {'Artistic Gymnastic':'Artistic Gymnastics',
 'Baseball/Softball':'Baseball',
 'Beach Volley':'Beach Volleyball',
 'Beach Volleybal':'Beach Volleyball',
 'Beach Volleyball':'Beach Volleyball',
 'Beach volleyball':'Beach Volleyball',
 'Boxing.':'Boxing',
 'boxing':'Boxing',
 'Rugby.': 'Rugby',
 'Skateboarding.':'Skateboarding',
 'Softball': 'Softball/Baseball',
 'Wrestling.':'Wrestling',
 'rugby':'Rugby',
 'volleyball':'Volleyball'
}

# %%
eventscopy['sport'].replace(mapper,inplace=True)

# %%
eventscopy#.merge(venues,how='left', on='venue')
# Out:
#            date  time     sport                             venue  \
# 0    2021-07-21  1:00  Baseball  Fukushima Azuma Baseball Stadium
# 1    2021-07-21  8:30  Football                      Sapporo Dome
# 2    2021-07-21  9:00  Football                    Miyagi Stadium
# 3    2021-07-21  9:30  Football                     Tokyo Stadium
# 4    2021-07-22  1:00  Baseball  Fukushima Azuma Baseball Stadium
# ...         ...   ...       ...                               ...
# 1890 2021-07-28  0:30    Rowing               Sea Forest Waterway
# 1891 2021-07-29  0:30    Rowing               Sea Forest Waterway
# 1892 2021-07-29  0:30    Rowing               Sea Forest Waterway
# 1893 2021-07-29  0:30    Rowing               Sea Forest Waterway
# 1894 2021-07-29  0:30    Rowing               Sea Forest Waterway
#
#                                            event
# 0                             Australia vs Japan
# 1        Women's Group E: Great Britain vs Chile
# 2               Women's Group F: China vs Brazil
# 3       Women's Group G: Sweden vs United States
# 4                        United States vs Canada
# ...                                          ...
# 1890          Men's Single Sculls Semifinals A/B
# 1891     Lightweight Men's Double Sculls Final B
# 1892   Lightweight Women's Double Sculls Final B
# 1893               Women's Single Sculls Final D
# 1894                 Men's Single Sculls Final D
#
# [1895 rows x 5 columns]

# %%
venues
# Out:
#                                venue                  sport  \
# 0                    Olympic Stadium       Opening Ceremony
# 1                    Olympic Stadium       Closing Ceremony
# 2                    Olympic Stadium              Athletics
# 3                    Olympic Stadium               Football
# 4       Tokyo Metropolitan Gymnasium           Table Tennis
# 5            Yoyogi National Stadium               Handball
# 6                     Nippon Budokan                   Judo
# 7                     Nippon Budokan                 Karate
# 8          Tokyo International Forum          Weightlifting
# 9                    Kokugikan Arena                 Boxing
# 10                   Equestrian Park             Equestrian
# 11      Musashino Forest Sport Plaza              Badminton
# 12      Musashino Forest Sport Plaza      Modern Pentathlon
# 25   35.630141395249126, 139.7762643781928
# 26   35.630141395249126, 139.7762643781928
# 27   35.62426208355979, 139.76843705331703
# 28    35.62349586496833, 139.7773659975334
# 29    35.62349586496833, 139.7773659975334
# 30   35.59269081886343, 139.75405101776522
# 31   35.60759886347745, 139.80957901217784
# 32    35.60796457817903, 139.8147625026683
# 33    35.60796457817903, 139.8147625026683
# 34  35.643601065815034, 139.85504382104045
# 35   35.65025376166539, 139.82892847281852
# 36   35.65154002713155, 139.81526845227876
# 37   35.65154002713155, 139.81526845227876
# 38   35.65154002713155, 139.81526845227876
# 39   35.647754733125474, 139.8195228619168
# 40   43.05988480448009, 141.34661238831993
# 41   35.64977449961884, 140.03645074412134
# 42   35.64977449961884, 140.03645074412134
# 43   35.64977449961884, 140.03645074412134
# 44  35.336127096773154, 140.39491001303773
# 45   35.895211316703495, 139.6314078235249
# 46    35.7811380207295, 139.58779467064903
# 47  35.899811713519725, 139.40574870339583
# 48   35.29979336326726, 139.48406276201857
# 49   35.01222390470476, 139.01558129892814
# 50  35.008554056580564, 139.01269403251226
# 51  35.372702911045124, 138.92936859906928
# 52    37.72216480340486, 140.3640114979229
# 53   35.44332814187166, 139.64046498472052
# 54   43.01517544330762, 141.41041300340524
# 55   38.33557331725407, 140.95096377309127
# 56   35.99213056967567, 140.64152126184229
# 57  35.903408731875246, 139.71816554795595
# 58   35.51002465197473, 139.60687650162822

# %%
eventscopy['medal_ceremony'] = eventscopy['event'].str.contains('Medal')

# %%
eventscopy=eventscopy.merge(venues[['venue','location']],how='left',on='venue').reset_index(drop=True).copy()

# %%
eventscopy
# Out:
#            date  time     sport                             venue  \
# 0    2021-07-21  1:00  Baseball  Fukushima Azuma Baseball Stadium
# 1    2021-07-21  8:30  Football                      Sapporo Dome
# 2    2021-07-21  9:00  Football                    Miyagi Stadium
# 3    2021-07-21  9:30  Football                     Tokyo Stadium
# 4    2021-07-21  9:30  Football                     Tokyo Stadium
# ...         ...   ...       ...                               ...
# 3591 2021-07-29  0:30    Rowing               Sea Forest Waterway
# 3592 2021-07-29  0:30    Rowing               Sea Forest Waterway
# 3593 2021-07-29  0:30    Rowing               Sea Forest Waterway
# 3594 2021-07-29  0:30    Rowing               Sea Forest Waterway
# 3595 2021-07-29  0:30    Rowing               Sea Forest Waterway
#
#                                            event  medal_ceremony  \
# 0                             Australia vs Japan           False
# 1        Women's Group E: Great Britain vs Chile           False
# 2               Women's Group F: China vs Brazil           False
# 3       Women's Group G: Sweden vs United States           False
# 4       Women's Group G: Sweden vs United States           False
# ...                                          ...             ...
# 3591   Lightweight Women's Double Sculls Final B           False
# 3592               Women's Single Sculls Final D           False
# 3593               Women's Single Sculls Final D           False
# 3594                 Men's Single Sculls Final D           False
# 3595                 Men's Single Sculls Final D           False
#
#                                    location
# 0      37.72216480340486, 140.3640114979229
# 1     43.01517544330762, 141.41041300340524
# 2     38.33557331725407, 140.95096377309127
# 3     35.66446761779039, 139.52756286092847
# 4     35.66446761779039, 139.52756286092847
# ...                                     ...
# 3591   35.60796457817903, 139.8147625026683
# 3592   35.60796457817903, 139.8147625026683
# 3593   35.60796457817903, 139.8147625026683
# 3594   35.60796457817903, 139.8147625026683
# 3595   35.60796457817903, 139.8147625026683
#
# [3596 rows x 7 columns]

# %%
eventscopy.to_csv('test.csv',index=False)
os.startfile('test.csv')
